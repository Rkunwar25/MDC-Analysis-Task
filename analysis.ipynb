# %% [markdown]
# ## ANALYSING YOUTUBE VIDEO TRENDS

# %% [markdown]
# 1. FOR THE FILE CAVIDEOS - CANADIAN VIDEOS

# %%
# Importing necessary libraries/packages : : 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sn
import warnings
warnings.filterwarnings("ignore")

# %%
d=pd.read_csv("CAvideos.csv")

# %%
a=d.columns
print("The columns are : ")
for i in a:
    print(i)
# Out:
# The columns are :
# video_id
# trending_date
# title
# channel_title
# category_id
# publish_time
# tags
# views
# likes
# dislikes
# comment_count
# thumbnail_link
# comments_disabled
# ratings_disabled
# video_error_or_removed
# description

# %%
rc=d.shape
print("Given dataset consists of",rc[0],"number of rows and",rc[1],"number of columns.")
# Out:
# Given dataset consists of 40881 number of rows and 16 number of columns.

# %%
print("Description of different fields : ")
d.dtypes
# Out:
# Description of different fields :
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
d.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %%
d.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %%
print("Number of videos trending during different dates : ")
d['trending_date'].value_counts()
# Out:
# Number of videos trending during different dates :
# trending_date
# 17.14.11    200
# 18.19.02    200
# 18.29.03    200
# 18.30.03    200
# 18.31.03    200
#            ...
# 18.02.02    195
# 18.13.02    195
# 18.31.01    191
# 18.01.02    190
# 18.14.05    171
# Name: count, Length: 205, dtype: int64

# %%
plt.figure(figsize=(10,8))

# Distribution of Views
plt.subplot(2, 2, 1)
plt.hist(d['views'], bins=50, color='skyblue')
plt.title('Distribution of Views')
plt.xlabel('Views')
plt.ylabel('Frequency')

# Distribution of Likes
plt.subplot(2, 2, 2)
plt.hist(d['likes'], bins=50, color='lightgreen')
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')

# Distribution of Dislikes
plt.subplot(2, 2, 3)
plt.hist(d['dislikes'], bins=50, color='lightcoral')
plt.title('Distribution of Dislikes')
plt.xlabel('Dislikes')
plt.ylabel('Frequency')

# Distribution of Comment Count
plt.subplot(2, 2, 4)
plt.hist(d['comment_count'], bins=50, color='orange')
plt.title('Distribution of Comment Count')
plt.xlabel('Comment Count')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Analysis : Basing on the above graphs, we can visualise trends as follows:
# 1. For views column, majority of the videos fall into view count of about 0.0 to 0.2 hundred millions. It means the majority trending videos have views of about 10 to 20 millions.
# 2. For likes column, majority of the videos fall into view count of about less than 1 million.
# 3. Dislikes lie in range of less than 0.2 million indicating lesser the amount of dislikes, more the video trends.
# 4. Comments are also in range of less than 0.2 million.
#
# All this indicates that newly released videos tend to TREND for a good amount of time and with time, as people view more and more they start to become less trendy.
#
#
# Lets analyse further :

# %%
corr_matrix = d[['views', 'likes', 'dislikes', 'comment_count']].corr()
plt.figure(figsize=(8,6))
sn.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The above correlation map indicates relation between different categorical values.
# we infer the following :
# 1. More views indicate more likes, making video more trending.
# 2. More comments indicate more likes, another reason showing how people's interaction is almost proportional to whether they like a video or not.
# 3. There is a good diffrence between likes and dislikes, indicating people clearly either like a video or dislike a video; no in betweens.

# %%
category_views = d.groupby('category_id')['views'].mean().sort_values(ascending=False)
category_likes = d.groupby('category_id')['likes'].mean().sort_values(ascending=False)
print("Most popular categories by average views:\n", category_views)
print("\nMost popular categories by average likes:\n", category_likes)
# Out:
# Most popular categories by average views:
#  category_id
# 10    3.532525e+06
# 30    2.853415e+06
# 29    1.562184e+06
# 1     1.426729e+06
# 28    1.233845e+06
# 17    1.075584e+06
# 24    1.016372e+06
# 23    9.828886e+05
# 20    9.237592e+05
# 22    7.864136e+05
# 26    7.826839e+05
# 15    6.384612e+05
# 43    5.770122e+05
# 2     5.667594e+05
# 27    5.366028e+05
# 25    3.882207e+05
# 19    3.667014e+05
# Name: views, dtype: float64
#
# Most popular categories by average likes:
#  category_id
# 10    151285.856339
# 29    138413.689189
# 23     51960.422475
# 30     42150.833333
# 20     38487.017857
# 1      37767.962621
# 28     37068.916017
# 24     28789.341536
# 22     25673.219001
# 26     25502.293971
# 15     23931.533875
# 17     21330.972013
# 27     21162.867810
# 2      13405.422096
# 19      9568.658163
# 25      7863.682135
# 43      4752.120968
# Name: likes, dtype: float64

# %% [markdown]
# Inferences :
# 1. Category ID 10 has the highest average number of views at approximately 3.53 million.
# 2. Category ID 30 follows with an average of around 2.85 million views.
# 3. Category ID 29 has an average of about 1.56 million views.
# 4. Category ID 10 has the highest average number of likes at approximately 151,286 likes.
# 5. Category ID 29 follows with an average of around 138,414 likes.
#
# This indicates that category 10 videos tend to have highest average views and likes and therefore videos in this category TREND more.

# %%
from collections import Counter
tags = d['tags'].str.split('|').explode()
common_tags = Counter(tags).most_common(20)

tags, counts = zip(*common_tags)
plt.figure(figsize=(10,6))
plt.barh(tags, counts, color='purple')
plt.xlabel('Frequency')
plt.title('Top 20 Most Common Tags')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# The most viewership is on videos with tag "Funny" indicating more histerical videos are likely to be more trending.

# %% [markdown]
# ## In conclusion, a video in Canada trends more with condition :
# 1. It is newly released, and views are significantly low
# 2. More views and likes; whereas dislikes are less.
# 3. Most of the videos are of "funny" tagged.

# %% [markdown]
# ## ANALYSIS FOR VIDEOS IN USA

# %%
d=pd.read_csv("USvideos.csv")

# %%
a=d.columns
print("The columns are : ")
for i in a:
    print(i)
# Out:
# The columns are :
# video_id
# trending_date
# title
# channel_title
# category_id
# publish_time
# tags
# views
# likes
# dislikes
# comment_count
# thumbnail_link
# comments_disabled
# ratings_disabled
# video_error_or_removed
# description

# %%
rc=d.shape
print("Given dataset consists of",rc[0],"number of rows and",rc[1],"number of columns.")
# Out:
# Given dataset consists of 40949 number of rows and 16 number of columns.

# %%
print("Description of different fields : ")
d.dtypes
# Out:
# Description of different fields :
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
d.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
d.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
print("Number of videos trending during different dates : ")
d['trending_date'].value_counts()
# Out:
# Number of videos trending during different dates :
# trending_date
# 17.14.11    200
# 18.16.04    200
# 18.01.04    200
# 18.02.04    200
# 18.03.04    200
#            ...
# 18.01.02    197
# 18.31.01    197
# 18.03.02    196
# 18.02.02    196
# 18.04.02    196
# Name: count, Length: 205, dtype: int64

# %%
plt.figure(figsize=(10,8))

# Distribution of Views
plt.subplot(2, 2, 1)
plt.hist(d['views'], bins=50, color='skyblue')
plt.title('Distribution of Views')
plt.xlabel('Views')
plt.ylabel('Frequency')

# Distribution of Likes
plt.subplot(2, 2, 2)
plt.hist(d['likes'], bins=50, color='lightgreen')
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')

# Distribution of Dislikes
plt.subplot(2, 2, 3)
plt.hist(d['dislikes'], bins=50, color='lightcoral')
plt.title('Distribution of Dislikes')
plt.xlabel('Dislikes')
plt.ylabel('Frequency')

# Distribution of Comment Count
plt.subplot(2, 2, 4)
plt.hist(d['comment_count'], bins=50, color='orange')
plt.title('Distribution of Comment Count')
plt.xlabel('Comment Count')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Analysis : Basing on the above graphs, we can visualise trends of videos in US as follows:
# 1. For views column, majority of the videos fall into view count of about 0.0 to 0.5 hundred millions. It means the majority trending videos have views of about 10 to 50 millions.
# 2. For likes column, majority of the videos fall into view count of about less than 1 million.
# 3. Dislikes lie in range of less than 0.25 million indicating lesser the amount of dislikes, more the video trends.
# 4. Comments are also in range of  than 0.3 million.
#
# Lets analyse further :

# %%
corr_matrix = d[['views', 'likes', 'dislikes', 'comment_count']].corr()
plt.figure(figsize=(8,6))
sn.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Strong correlation between likes and number of views, and strong correlation between comments and likes indicate more viewed, liked and commented videos are likely to trend more.

# %%
category_views = d.groupby('category_id')['views'].mean().sort_values(ascending=False)
category_likes = d.groupby('category_id')['likes'].mean().sort_values(ascending=False)
print("Most popular categories by average views:\n", category_views)
print("\nMost popular categories by average likes:\n", category_likes)
# Out:
# Most popular categories by average views:
#  category_id
# 10    6.201003e+06
# 1     3.106250e+06
# 29    2.963884e+06
# 20    2.620831e+06
# 24    2.067883e+06
# 17    2.025969e+06
# 22    1.531835e+06
# 23    1.480308e+06
# 28    1.452627e+06
# 2     1.355965e+06
# 26    9.837301e+05
# 43    9.035273e+05
# 19    8.546196e+05
# 15    8.311435e+05
# 27    7.129408e+05
# 25    5.925877e+05
# Name: views, dtype: float64
#
# Most popular categories by average likes:
#  category_id
# 29    259923.614035
# 10    218918.199011
# 20     84502.183599
# 1      70787.836247
# 23     62582.223315
# 22     58135.825234
# 24     53243.325070
# 17     45363.942502
# 26     39286.076942
# 28     34374.276551
# 27     29745.031401
# 15     21055.110870
# 43     18993.666667
# 19     12030.462687
# 2      11056.395833
# 25      7298.364696
# Name: likes, dtype: float64

# %% [markdown]
# The highest average views are on videos of category 10 whereas highest average likes is on videos of category 29; this indicates videos of categories 10, 29 are likely to trend more compared to others.

# %%
from collections import Counter
tags = d['tags'].str.split('|').explode()
common_tags = Counter(tags).most_common(20)

tags, counts = zip(*common_tags)
plt.figure(figsize=(10,6))
plt.barh(tags, counts, color='purple')
plt.xlabel('Frequency')
plt.title('Top 20 Most Common Tags')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Like Canada, the videos falling in tags 'funny' , 'comedy' are trending more than others.

# %% [markdown]
# ## CONCLUSION :

# %% [markdown]
# We conclude that in US, videos with more views, likes and videos with tags funny and comedy trend more than other videos,.

# %% [markdown]
# ## ANALYSIS FOR INDIA VIDEOS ON YOUTUBE

# %%
d=pd.read_csv("INvideos.csv")

# %%
plt.figure(figsize=(10,8))

# Distribution of Views
plt.subplot(2, 2, 1)
plt.hist(d['views'], bins=50, color='skyblue')
plt.title('Distribution of Views')
plt.xlabel('Views')
plt.ylabel('Frequency')

# Distribution of Likes
plt.subplot(2, 2, 2)
plt.hist(d['likes'], bins=50, color='lightgreen')
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')

# Distribution of Dislikes
plt.subplot(2, 2, 3)
plt.hist(d['dislikes'], bins=50, color='lightcoral')
plt.title('Distribution of Dislikes')
plt.xlabel('Dislikes')
plt.ylabel('Frequency')

# Distribution of Comment Count
plt.subplot(2, 2, 4)
plt.hist(d['comment_count'], bins=50, color='orange')
plt.title('Distribution of Comment Count')
plt.xlabel('Comment Count')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Inferences :

# %% [markdown]
# More trending videos in India have :
# 1. views between 10 to 20 millions
# 2. likes less than 2 millions
# 3. dislikes less than 2 millions
# 4. Comments less tha 2 lakhs.

# %%
corr_matrix = d[['views', 'likes', 'dislikes', 'comment_count']].corr()
plt.figure(figsize=(8,6))
sn.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Trending videos have more likes-view correlation, similarly more comments-views corrleation and also more likes-comments correlation.

# %%
from collections import Counter
tags = d['tags'].str.split('|').explode()
common_tags = Counter(tags).most_common(20)

tags, counts = zip(*common_tags)
plt.figure(figsize=(10,6))
plt.barh(tags, counts, color='purple')
plt.xlabel('Frequency')
plt.title('Top 20 Most Common Tags')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# In India the trending videos have tags  : funny,comedy. These videos trend significantly more than others.

# %% [markdown]
# ## ANALYSIS FOR DENMARK VIDEOS

# %%
d=pd.read_csv("DEvideos.csv")





plt.figure(figsize=(10,8))

# Distribution of Views
plt.subplot(2, 2, 1)
plt.hist(d['views'], bins=50, color='skyblue')
plt.title('Distribution of Views')
plt.xlabel('Views')
plt.ylabel('Frequency')

# Distribution of Likes
plt.subplot(2, 2, 2)
plt.hist(d['likes'], bins=50, color='lightgreen')
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')

# Distribution of Dislikes
plt.subplot(2, 2, 3)
plt.hist(d['dislikes'], bins=50, color='lightcoral')
plt.title('Distribution of Dislikes')
plt.xlabel('Dislikes')
plt.ylabel('Frequency')

# Distribution of Comment Count
plt.subplot(2, 2, 4)
plt.hist(d['comment_count'], bins=50, color='orange')
plt.title('Distribution of Comment Count')
plt.xlabel('Comment Count')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()




corr_matrix = d[['views', 'likes', 'dislikes', 'comment_count']].corr()
plt.figure(figsize=(8,6))
sn.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()





from collections import Counter
tags = d['tags'].str.split('|').explode()
common_tags = Counter(tags).most_common(20)

tags, counts = zip(*common_tags)
plt.figure(figsize=(10,6))
plt.barh(tags, counts, color='purple')
plt.xlabel('Frequency')
plt.title('Top 20 Most Common Tags')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Conclusion :
# More trending videos in Denmark have :
# 1. Views less than 20 millions.
# 2. likes less than 1 million.
# 3. dislikes and comments less than 0.2 million
# 4. strong correlation between likes and views, likes and comments.
# 5. no specific tag, but nearly videos in 2018 trended more than any other videos.

# %% [markdown]
# ## ANALYSIS FOR VIDEOS IN GREAT BRITAIN

# %%
d=pd.read_csv("GBvideos.csv")





plt.figure(figsize=(10,8))

# Distribution of Views
plt.subplot(2, 2, 1)
plt.hist(d['views'], bins=50, color='skyblue')
plt.title('Distribution of Views')
plt.xlabel('Views')
plt.ylabel('Frequency')

# Distribution of Likes
plt.subplot(2, 2, 2)
plt.hist(d['likes'], bins=50, color='lightgreen')
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')

# Distribution of Dislikes
plt.subplot(2, 2, 3)
plt.hist(d['dislikes'], bins=50, color='lightcoral')
plt.title('Distribution of Dislikes')
plt.xlabel('Dislikes')
plt.ylabel('Frequency')

# Distribution of Comment Count
plt.subplot(2, 2, 4)
plt.hist(d['comment_count'], bins=50, color='orange')
plt.title('Distribution of Comment Count')
plt.xlabel('Comment Count')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()




corr_matrix = d[['views', 'likes', 'dislikes', 'comment_count']].corr()
plt.figure(figsize=(8,6))
sn.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()





from collections import Counter
tags = d['tags'].str.split('|').explode()
common_tags = Counter(tags).most_common(20)

tags, counts = zip(*common_tags)
plt.figure(figsize=(10,6))
plt.barh(tags, counts, color='purple')
plt.xlabel('Frequency')
plt.title('Top 20 Most Common Tags')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Conclusion :
# 1. Trending videos are withen range of 0 to 100 millions viewership wise.
# 2. Videos having 0 to 0.5 million likes, 0 to 0.25 million dislikes and 0 to  0.2 million comments like;y to be more trending.
# 3. Strong correlation between likes-views, likes and comments.
# 4. Tags like "funny" "comedy" and "music" trend more.

# %% [markdown]
# ## ANALYSIS FOR FRANCE VIDEOS

# %%
d=pd.read_csv("FRvideos.csv")





plt.figure(figsize=(10,8))

# Distribution of Views
plt.subplot(2, 2, 1)
plt.hist(d['views'], bins=50, color='skyblue')
plt.title('Distribution of Views')
plt.xlabel('Views')
plt.ylabel('Frequency')

# Distribution of Likes
plt.subplot(2, 2, 2)
plt.hist(d['likes'], bins=50, color='lightgreen')
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')

# Distribution of Dislikes
plt.subplot(2, 2, 3)
plt.hist(d['dislikes'], bins=50, color='lightcoral')
plt.title('Distribution of Dislikes')
plt.xlabel('Dislikes')
plt.ylabel('Frequency')

# Distribution of Comment Count
plt.subplot(2, 2, 4)
plt.hist(d['comment_count'], bins=50, color='orange')
plt.title('Distribution of Comment Count')
plt.xlabel('Comment Count')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()




corr_matrix = d[['views', 'likes', 'dislikes', 'comment_count']].corr()
plt.figure(figsize=(8,6))
sn.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()





from collections import Counter
tags = d['tags'].str.split('|').explode()
common_tags = Counter(tags).most_common(20)

tags, counts = zip(*common_tags)
plt.figure(figsize=(10,6))
plt.barh(tags, counts, color='purple')
plt.xlabel('Frequency')
plt.title('Top 20 Most Common Tags')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Conclusion :
# Videos in France trend for following conditions :
# 1. views less than 20 millions, likes than 1 million, dislikes less than 0.2 million and comments also less than 0.2 millions.
# 2. Strong correlation between likes-views, likes-comments, views-comments.
# 3. Tags with more trends : humour , football.

# %% [markdown]
# Similarly we can analyse trends for other country datasets as well.
